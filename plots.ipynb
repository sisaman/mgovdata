# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import import_ipynb
import logic
# Out:
# importing Jupyter notebook from logic.ipynb
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
logic.draw_request_counts('both')

# %%
logic.draw_request_counts('failed')

# %%
logic.draw_request_counts('ratio')

# %%
logic.draw_runtime_stats()

# %%
logic.draw_request_counts_by_gateway('sabteahval', interval='day')

# %%
logic.draw_request_counts_by_gateway(interval='day')

# %%
logic.draw_request_counts_by_gateway('tamin', interval='week')

# %%
logic.draw_request_counts_by_gateway('hami', interval='week')

# %%
logic.draw_request_counts_by_gateway('karpousheh', interval='week')

# %%
logic.draw_runtime_stats_by_gateway('hami', interval='week')

# %%
logic.draw_user_count_prediction()

# %%
logic.draw_request_count_prediction(gateway='sabteahval', start_date='07/2018', end_date='11/2018')
